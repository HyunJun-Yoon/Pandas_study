# %% [markdown]
# 1. What about reading from csv file only two columns and ignore others?

# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', usecols=['City', 'State'])

# %%
ufo.columns
# Out:
# Index(['City', 'State'], dtype='object')

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', usecols=[0, 4])

# %%
ufo.columns
# Out:
# Index(['City', 'Time'], dtype='object')

# %% [markdown]
# 2. What is fastest method to read from csv file?
# answer: If you want to look at just three rows of big data set you can do below

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', nrows=3)
ufo
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# 3. How do Dataframes and Series work with regard to selecting individual entries and iteration?

# %%
for c in ufo.City:
    print(c)
# Out:
# Ithaca
# Willingboro
# Holyoke

# %%
for index, row in ufo.iterrows():
    print(index, row.City, row.State)
# Out:
# 0 Ithaca NY
# 1 Willingboro NJ
# 2 Holyoke CO

# %% [markdown]
# 4. What's the best way to drop every non-numeric columns from a Dataframe?

# %%
import numpy as np
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.dtypes
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
asia = drinks[drinks.continent == 'Asia']
asia.sort_values('total_litres_of_pure_alcohol')
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 128              Pakistan              0                0              0
# 90                 Kuwait              0                0              0
# 79                   Iran              0                0              0
# 46            North Korea              0                0              0
# 103              Maldives              0                0              0
# 13             Bangladesh              0                0              0
# 190                 Yemen              6                0              0
# 171           Timor-Leste              1                1              4
# 149          Saudi Arabia              0                5              0
# 78              Indonesia              5                1              0
# 116               Myanmar              5                1              0
# ...

# %%
drinks.describe() #only shows numeric columns
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe(include='all')
# Out:
#            country  beer_servings  spirit_servings  wine_servings  \
# count          193     193.000000       193.000000     193.000000
# unique         193            NaN              NaN            NaN
# top     Uzbekistan            NaN              NaN            NaN
# freq             1            NaN              NaN            NaN
# mean           NaN     106.160622        80.994819      49.450777
# std            NaN     101.143103        88.284312      79.697598
# min            NaN       0.000000         0.000000       0.000000
# 25%            NaN      20.000000         4.000000       1.000000
# 50%            NaN      76.000000        56.000000       8.000000
# 75%            NaN     188.000000       128.000000      59.000000
# max            NaN     376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       193
# unique                           NaN         6
# ...

# %%
drinks.describe(include=['object', 'float64'])
# Out:
#            country  total_litres_of_pure_alcohol continent
# count          193                    193.000000       193
# unique         193                           NaN         6
# top     Uzbekistan                           NaN    Africa
# freq             1                           NaN        53
# mean           NaN                      4.717098       NaN
# std            NaN                      3.773298       NaN
# min            NaN                      0.000000       NaN
# 25%            NaN                      1.300000       NaN
# 50%            NaN                      4.200000       NaN
# 75%            NaN                      7.200000       NaN
# max            NaN                     14.400000       NaN
